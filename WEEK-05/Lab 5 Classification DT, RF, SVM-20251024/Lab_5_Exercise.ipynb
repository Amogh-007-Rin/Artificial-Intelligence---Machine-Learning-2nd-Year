# %% [markdown]
# # **Breast Cancer Wisconsin (Diagnostic)**
# You will building models for detecting Breast Cancer. You will use this dataset. Check its source from [here](https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic)

# %% [markdown]
# First you will load the data from SKLEARN library and then divide it into:
#
# - **X features: 30 numeric features (e.g., mean radius, texture, perimeter)**
#
# - **y labels:  0 = malignant, 1 = benign**
#
# You will also check its shape
#
#
# ```
#
# print(X.shape)
# print(X.head())
#
# ```

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Load dataset
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name='target')


print(X.shape)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
# Check the features:

X.head()

# %%
# Check the labels:

y.head()

# %%
# Check how many patients in the data has malignant or benign tumour

# %%
#Divid the data into train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # **Exercise 1:**
#
# Train both a Random Forest and a Decision Tree Classifier on the data and compare their performance.
#
# Use Lab_5 code as a guide

# %% [markdown]
# **Random Forest Classifie**

# %% [markdown]
# **Decision Tree Classifier**

# %% [markdown]
# **Support Vector Machine (SVM)**

# %% [markdown]
# # **Exercise 2 Advanced**
#
# Try to change the parameters for each of the three models and see how it will affect the performance
